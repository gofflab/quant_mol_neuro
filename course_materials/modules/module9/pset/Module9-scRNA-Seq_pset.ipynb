# %% [markdown]
# # Module 9 Problem Set - Single-Cell RNA-Seq Analysis
#
# **Instructions:**
# - Complete all questions in this notebook
# - For coding questions, write your code in the designated cells
# - For conceptual questions, write your answers in markdown cells
# - Make sure to run all prerequisite cells from the original Module9 notebook before attempting these problems
# - Total Points: 10

# %% [markdown]
# ---
# ## Setup: Load Required Libraries and Data
#
# **Note:** You should have already completed the preprocessing steps from Module 9 before starting this problem set. The following assumes you have an `adata` object that has been:
# - Filtered for quality
# - Normalized
# - Log-transformed
# - Selected for highly variable genes
# - Scaled
# - PCA computed
# - Neighborhood graph computed
#
# **Note:** You will _not_ need to complete the scFates pseudotime analysis for this problem set.

# %%
import numpy as np
import pandas as pd
import scanpy as sc
import matplotlib.pyplot as plt
import seaborn as sns
import plotnine as pn

sc.settings.verbosity = 3
sc.settings.set_figure_params(dpi=80, facecolor='white')

# %% [markdown]
# ---
# ## Load previouly saved AnnData object
#
# Let's start by loading the previously saved AnnData object from the Module 9 notebook. The `sc.read_h5ad()` function will read the .h5ad file that we saved using `adata.write_h5ad()`. Make sure to adjust the file path as necessary to point to where your .h5ad data file is stored.

# %%
adata = sc.read_h5ad('../notebooks/data/E18_mouse_cortex.h5ad')

# %% [markdown]
# ---
# ## Question 1: Understanding Quality Control Metrics
#
# **Part A :** Explain why we might filter cells based on mitochondrial gene percentage in single-cell RNA-seq experiments. What biological condition does high mitochondrial content typically indicate? What is a reasonable threshold for `pct_counts_mt` and why might this threshold vary between tissue or cell types? When might you _not_ want to filter based on mitochondrial gene ratio?
#
# **Part B :** In the original analysis, we filtered cells with `min_genes=200`. Explain what happens if this threshold is:
# 1. Too low (e.g., 50 genes)
# 2. Too high (e.g., 2000 genes)
#
# What factors should you consider when setting this threshold?

# %% [markdown]
# **Your Answer:**
#
# *Write your answer here*
#
# A)
#
# B)

# %% [markdown]
# ---
# ## Question 2: Leiden Clustering with Different Resolutions
#
# The original analysis used a default resolution of 0.3 for Leiden clustering. Your task is to:
#
# 1. Perform Leiden clustering with three different resolution values: 0.1, 0.5, and 1.0
# 2. Store each clustering result with a unique name (e.g., 'leiden_0.1', 'leiden_0.5', 'leiden_1.0') #You can use the 'key_added' parameter in `sc.tl.leiden()` to create new columns in `adata.obs` and store the results.
# 3. Create a figure with 3 UMAP plots showing the clustering results for each resolution
# 4. Report the number of clusters identified at each resolution
# 5. Explain how resolution affects cluster granularity and which resolution you would choose for this dataset and why

# %%
# Your code here
# Step 1: Perform clustering at different resolutions
resolutions = [0.1, 0.5, 1.0]
for res in resolutions:
    <your code here>

# Step 2: Create visualization

# Step 3: Report number of clusters

# %% [markdown]
# **Your Explanation:**
#
# *Write your interpretation here*

# %% [markdown]
# ---
# ## Question 3: Highly Variable Genes Selection
#
# **Part A :** Explain the purpose of selecting highly variable genes in single-cell RNA-seq analysis. Why don't we use all genes for downstream analysis? What biological and technical factors contribute to gene expression variability?
#
# **Part B :** The original analysis used parameters `min_mean=0.0125, max_mean=4, min_disp=0.25` for highly variable gene selection. Re-run the highly variable gene selection with more stringent parameters (`min_mean=0.1, max_mean=3, min_disp=0.5`) and report:
# 1. How many highly variable genes are selected with the new parameters?
# 2. What trade-offs exist when using more stringent vs. more lenient parameters?

# %% [markdown]
# **Part A Answer:**
#
# *Write your answer here*

# %%
# Part B Code
#

# %% [markdown]
# **Part B Answer:**
#
# *Write your interpretation here*

# %% [markdown]
# ---
# ## Question 4: Finding Marker Genes by Expression Criteria
#
# Write code to identify genes that meet the following criteria:
#
# 1. **Highly expressed in cluster 0** (using the original leiden clustering with resolution=0.3):
#    - Mean expression in cluster 0 > 1.0 (in log-normalized space; `layer=log1p`)
#    - Mean expression in cluster 0 is at least 2-fold higher than the mean across all other clusters
#    - *Hint: You can use sc.get.aggregate to compute aggregated expression values for a each element of a given annotation (e.g., cluster labels).*
# ```
#    aggregated_data = sc.get.aggregate(
#     adata,
#     by="???", # 'group by which to aggregate'
#     func="mean", # or 'sum', 'median', etc.
#     layer="???" # Or None to use adata.X
# )
# ```
# 2. Display:
#    - The top 10 genes meeting these criteria, sorted by fold-change
#    - Create a dot plot showing expression of these top 10 genes across all clusters (`sc.pl.dotplot()`)
#    - Create a UMAP plot colored by the expression of the top 3 genes

# %%
# Your code here

# Step 1: Calculate mean expression per cluster

# Step 2: Find genes meeting criteria

# Step 3: Create visualizations

# %% [markdown]
# ---
# ## Question 5: Understanding PCA and Dimensionality Reduction
#
# **Part A :** Explain why we perform PCA before computing the neighborhood graph and UMAP in single-cell analysis. What are the advantages of working in PC space rather than the full gene expression space?
#
# **Part B :** Looking at the PCA variance ratio plot from the original analysis:
# 1. Approximately how many PCs capture most of the variance in this dataset?
# 2. What would be the consequence of using too few PCs (e.g., only 5)?
# 3. What would be the consequence of using too many PCs (e.g., 100)?

# %% [markdown]
# **Your Answer:**
#
# *Write your answer here*

# %% [markdown]
# ---
# ## Question 6: Differential Expression Analysis (15 points)
#
# Using the Leiden clustering results (resolution=0.3), perform a differential expression analysis to identify marker genes that distinguish excitatory neurons from other cell types.
#
# Based on the original analysis, excitatory neuron clusters are: ["0","1","4","5","6","8"]
#
# Your tasks:
# 1. Create a new column in `adata.obs` called 'cell_type' that labels cells as either 'excitatory' or 'other'
# 2. Use `sc.tl.rank_genes_groups()` to find differentially expressed genes between these two groups
# 3. Extract and display the top 20 upregulated genes in excitatory neurons
# 4. Create a volcano plot or visualization showing fold-change vs. statistical significance
# 5. Discuss: Do any of these top genes make biological sense as excitatory neuron markers?

# %%
# Your code here

# %% [markdown]
# **Your Discussion:**
#
# *Write your answer here*

# %% [markdown]
# ---
# ## Question 7: Finding Co-expressed Genes
#
# The gene *Pax6* is a key progenitor marker. Find genes that are strongly co-expressed with *Pax6* across all cells.
#
# Your tasks:
# 1. Calculate the correlation between *Pax6* expression and all other genes in the dataset
# 2. Identify the top 10 genes most positively correlated with *Pax6* (excluding *Pax6* itself)
# 3. Identify the top 10 genes most negatively correlated with *Pax6*
#
# **Hint:** Use correlation methods from numpy or scipy. Work with the log-normalized expression data (`log1p`).

# %%
# Your code here

# %% [markdown]
# **Your Interpretation:**
#
# *Write your answer here*

# %% [markdown]
# ---
# ## Question 8: Experimental Design Considerations
#
# You are planning a new single-cell RNA-seq experiment to study neuronal differentiation in a different brain region.
#
# Based on your experience analyzing this dataset, discuss:
#
# 1. **Sequencing depth:** How many reads per cell would you aim for and why? How does this relate to the gene detection sensitivity you observed in this dataset?
#
# 2. **Cell numbers:** How many cells would you aim to capture? What factors influence this decision?
#
# 3. **Replication:** How might you incorporate biological replicates into your experimental design? How many replicates would be sufficient to ensure robust conclusions?

# %% [markdown]
# **Your Answer:**
#
# *Write your answer here*
